# %% [markdown]
# You can order print and ebook versions of *Think Python 3e* from
# [Bookshop.org](https://bookshop.org/a/98697/9781098155438) and
# [Amazon](https://www.amazon.com/_/dp/1098155432?smid=ATVPDKIKX0DER&_encoding=UTF8&tag=oreilly20-20&_encoding=UTF8&tag=greenteapre01-20&linkCode=ur2&linkId=e2a529f94920295d27ec8a06e757dc7c&camp=1789&creative=9325).

# %%
from os.path import basename, exists

def download(url):
    filename = basename(url)
    if not exists(filename):
        from urllib.request import urlretrieve

        local, _ = urlretrieve(url, filename)
        print("Downloaded " + str(local))
    return filename

download('https://github.com/AllenDowney/ThinkPython/raw/v3/thinkpython.py');
download('https://github.com/AllenDowney/ThinkPython/raw/v3/diagram.py');
download('https://github.com/ramalho/jupyturtle/releases/download/2024-03/jupyturtle.py');

# %%
import thinkpython

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Functions and Interfaces
#
# This chapter introduces a module called `jupyturtle`, which allows you to create simple drawings by giving instructions to an imaginary turtle.
# We will use this module to write functions that draw squares, polygons, and circles -- and to demonstrate **interface design**, which is a way of designing functions that work together.

# %% [markdown]
# (section_turtle_module)=
# ## The jupyturtle module
#
# To use the `jupyturtle` module, we can import it like this.

# %%
import jupyturtle

# %% [markdown]
# Now we can use the functions defined in the module, like `make_turtle` and `forward`.

# %%
jupyturtle.make_turtle()
jupyturtle.forward(100)
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="250.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
#
# <g transform="rotate(-90.0,250.0,75.0) translate(250.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# `make_turtle` creates a **canvas**, which is a space on the screen where we can draw, and a turtle, which is represented by a circular shell and a triangular head.
# The circle shows the location of the turtle and the triangle indicates the direction it is facing.
#
# `forward` moves the turtle a given distance in the direction it's facing, drawing a line segment along the way.
# The distance is in arbitrary units -- the actual size depends on your computer's screen.
#
# We will use functions defined in the `jupyturtle` module many times, so it would be nice if we did not have to write the name of the module every time.
# That's possible if we import the module like this.

# %%
from jupyturtle import make_turtle, forward

# %% [markdown]
# This version of the import statement imports `make_turtle` and `forward` from the `jupyturtle` module so we can call them like this.

# %%
make_turtle()
forward(100)
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="250.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
#
# <g transform="rotate(-90.0,250.0,75.0) translate(250.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# `jupyturtle` provides two other functions we'll use, called `left` and `right`.
# We'll import them like this.

# %%
from jupyturtle import left, right

# %% [markdown]
# `left` causes the turtle to turn left. It takes one argument, which is the angle of the turn in degrees.
# For example, we can make a 90 degree left turn like this.

# %%
make_turtle()
forward(50)
left(90)
forward(50)
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="200.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="200.0" y1="75.0" x2="200.0" y2="25.0"
#     stroke="#663399" stroke-width="2" />
#
# <g transform="rotate(180.0,200.0,25.0) translate(200.0, 25.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# This program moves the turtle east and then north, leaving two line segments behind.
# Before you go on, see if you can modify the previous program to make a square.

# %% [markdown]
# ## Making a square
#
# Here's one way to make a square.

# %%
make_turtle()

forward(50)
left(90)

forward(50)
left(90)

forward(50)
left(90)

forward(50)
left(90)
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="200.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="200.0" y1="75.0" x2="200.0" y2="25.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="200.0" y1="25.0" x2="150.0" y2="25.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="25.0" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
#
# <g transform="rotate(-90.0,150.0,75.0) translate(150.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# Because this program repeats the same pair of lines four times, we can do the same thing more concisely with a `for` loop.

# %%
make_turtle()
for i in range(4):
    forward(50)
    left(90)
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="200.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="200.0" y1="75.0" x2="200.0" y2="25.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="200.0" y1="25.0" x2="150.0" y2="25.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="25.0" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
#
# <g transform="rotate(-90.0,150.0,75.0) translate(150.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# (section_encapsulation)=
# ## Encapsulation and generalization
#
# Let's take the square-drawing code from the previous section and put it in a function called `square`.

# %%
def square():
    for i in range(4):
        forward(50)
        left(90)

# %% [markdown]
# Now we can call the function like this.

# %%
make_turtle()
square()
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="200.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="200.0" y1="75.0" x2="200.0" y2="25.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="200.0" y1="25.0" x2="150.0" y2="25.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="25.0" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
#
# <g transform="rotate(-90.0,150.0,75.0) translate(150.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# Wrapping a piece of code up in a function is called **encapsulation**.
# One of the benefits of encapsulation is that it attaches a name to the code, which serves as a kind of documentation. Another advantage is that if you re-use the code, it is more concise to call a function twice than to copy and paste the body!
#
# In the current version, the size of the square is always `50`.
# If we want to draw squares with different sizes, we can take the length of the sides as a parameter.

# %%
def square(length):
    for i in range(4):
        forward(length)
        left(90)

# %% [markdown]
# Now we can draw squares with different sizes.

# %%
make_turtle()
square(30)
square(60)
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="180.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="180.0" y1="75.0" x2="180.0" y2="45.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="180.0" y1="45.0" x2="150.0" y2="45.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="45.0" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="75.0" x2="210.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="210.0" y1="75.0" x2="210.0" y2="15.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="210.0" y1="15.0" x2="150.0" y2="15.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="15.0" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
#
# <g transform="rotate(-90.0,150.0,75.0) translate(150.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# Adding a parameter to a function is called **generalization** because it makes the function more general: with the previous version, the square is always the same size; with this version it can be any size.
#
# If we add another parameter, we can make it even more general.
# The following function draws regular polygons with a given of sides.

# %%
def polygon(n, length):
    angle = 360 / n
    for i in range(n):
        forward(length)
        left(angle)

# %% [markdown]
# In a regular polygon with `n` sides, the angle between adjacent sides is `360 / n` degrees.
#
# The following example draws a `7`-sided polygon with side length `30`.

# %%
make_turtle()
polygon(7, 30)
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="180.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="180.0" y1="75.0" x2="198.7" y2="51.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="198.7" y1="51.5" x2="192.0" y2="22.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="192.0" y1="22.3" x2="165.0" y2="9.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="165.0" y1="9.3" x2="138.0" y2="22.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="138.0" y1="22.3" x2="131.3" y2="51.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="131.3" y1="51.5" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
#
# <g transform="rotate(270.0,150.0,75.0) translate(150.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# When a function has more than a few numeric arguments, it is easy to forget what they are, or what order they should be in.
# It can be a good idea to include the names of the parameters in the argument list.

# %%
make_turtle()
polygon(n=7, length=30)
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="180.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="180.0" y1="75.0" x2="198.7" y2="51.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="198.7" y1="51.5" x2="192.0" y2="22.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="192.0" y1="22.3" x2="165.0" y2="9.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="165.0" y1="9.3" x2="138.0" y2="22.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="138.0" y1="22.3" x2="131.3" y2="51.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="131.3" y1="51.5" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
#
# <g transform="rotate(270.0,150.0,75.0) translate(150.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# These are sometimes called "named arguments" because they include the parameter names.
# But in Python they are more often called **keyword arguments** (not to be confused with Python keywords like `for` and `def`).
#
# This use of the assignment operator, `=`, is a reminder about how arguments and parameters work -- when you call a function, the arguments are assigned to the parameters.

# %% [markdown]
# ## Approximating a circle
#
# Now suppose we want to draw a circle.
# We can do that, approximately, by drawing a polygon with a large number of sides, so each side is small enough that it's hard to see.
# Here is a function that uses `polygon` to draw a `30`-sided polygon that approximates a circle.

# %%
import math

def circle(radius):
    circumference = 2 * math.pi * radius
    n = 30
    length = circumference / n
    polygon(n, length)

# %% [markdown]
# `circle` takes the radius of the the circle as a parameter.
# It computes `circumference`, which is the circumference of a circle with the given radius.
# `n` is the number of sides, so `circumference / n` is the length of each side.
#
# This function might take a long time to run.
# We can speed it up by calling `make_turtle` with a keyword argument called `delay` that sets the time, in seconds, the turtle waits after each step.
# The default value is `0.2` seconds -- if we set it to `0.02` it runs about 10 times faster.

# %%
make_turtle(delay=0.02)
circle(30)
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="156.3" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="156.3" y1="75.0" x2="162.4" y2="73.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="162.4" y1="73.7" x2="168.2" y2="71.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="168.2" y1="71.1" x2="173.3" y2="67.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="173.3" y1="67.4" x2="177.5" y2="62.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="177.5" y1="62.8" x2="180.6" y2="57.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="180.6" y1="57.3" x2="182.5" y2="51.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="182.5" y1="51.4" x2="183.2" y2="45.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="183.2" y1="45.1" x2="182.5" y2="38.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="182.5" y1="38.9" x2="180.6" y2="32.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="180.6" y1="32.9" x2="177.5" y2="27.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="177.5" y1="27.4" x2="173.3" y2="22.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="173.3" y1="22.8" x2="168.2" y2="19.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="168.2" y1="19.1" x2="162.4" y2="16.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="162.4" y1="16.5" x2="156.3" y2="15.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="156.3" y1="15.2" x2="150.0" y2="15.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="15.2" x2="143.9" y2="16.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="143.9" y1="16.5" x2="138.1" y2="19.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="138.1" y1="19.1" x2="133.0" y2="22.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="133.0" y1="22.8" x2="128.8" y2="27.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="128.8" y1="27.4" x2="125.7" y2="32.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="125.7" y1="32.9" x2="123.7" y2="38.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="123.7" y1="38.9" x2="123.1" y2="45.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="123.1" y1="45.1" x2="123.7" y2="51.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="123.7" y1="51.4" x2="125.7" y2="57.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="125.7" y1="57.3" x2="128.8" y2="62.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="128.8" y1="62.8" x2="133.0" y2="67.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="133.0" y1="67.4" x2="138.1" y2="71.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="138.1" y1="71.1" x2="143.9" y2="73.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="143.9" y1="73.7" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
#
# <g transform="rotate(-90.0,150.0,75.0) translate(150.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# A limitation of this solution is that `n` is a constant, which means
# that for very big circles, the sides are too long, and for small
# circles, we waste time drawing very short sides.
# One option is to generalize the function by taking `n` as a parameter.
# But let's keep it simple for now.

# %% [markdown]
# ## Refactoring
#
# Now let's write a more general version of `circle`, called `arc`, that takes a second parameter, `angle`, and draws an arc of a circle that spans the given angle.
# For example, if `angle` is `360` degrees, it draws a complete circle. If `angle` is `180` degrees, it draws a half circle.
#
# To write `circle`, we were able to reuse `polygon`, because a many-sided polygon is a good approximation of a circle.
# But we can't use `polygon` to write `arc`.
#
# Instead, we'll create the more general version of `polygon`, called `polyline`.

# %%
def polyline(n, length, angle):
    for i in range(n):
        forward(length)
        left(angle)

# %% [markdown]
# `polyline` takes as parameters the number of line segments to draw, `n`, the length of the segments, `length`, and the angle between them, `angle`.
#
# Now we can rewrite `polygon` to use `polyline`.

# %%
def polygon(n, length):
    angle = 360.0 / n
    polyline(n, length, angle)

# %% [markdown]
# And we can use `polyline` to write `arc`.

# %%
def arc(radius, angle):
    arc_length = 2 * math.pi * radius * angle / 360
    n = 30
    length = arc_length / n
    step_angle = angle / n
    polyline(n, length, step_angle)

# %% [markdown]
# `arc` is similar to `circle`, except that it computes `arc_length`, which is a fraction of the circumference of a circle.
#
# Finally, we can rewrite `circle` to use `arc`.

# %%
def circle(radius):
    arc(radius,  360)

# %% [markdown]
# To check that these functions work as expected, we'll use them to draw something like a snail.
# With `delay=0`, the turtle runs as fast as possible.

# %%
make_turtle(delay=0)
polygon(n=20, length=9)
arc(radius=70, angle=70)
circle(radius=10)
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="159.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="159.0" y1="75.0" x2="167.6" y2="72.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="167.6" y1="72.2" x2="174.8" y2="66.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="174.8" y1="66.9" x2="180.1" y2="59.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="180.1" y1="59.6" x2="182.9" y2="51.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="182.9" y1="51.1" x2="182.9" y2="42.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="182.9" y1="42.1" x2="180.1" y2="33.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="180.1" y1="33.5" x2="174.8" y2="26.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="174.8" y1="26.2" x2="167.6" y2="21.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="167.6" y1="21.0" x2="159.0" y2="18.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="159.0" y1="18.2" x2="150.0" y2="18.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="18.2" x2="141.4" y2="21.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="141.4" y1="21.0" x2="134.2" y2="26.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="134.2" y1="26.2" x2="128.9" y2="33.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="128.9" y1="33.5" x2="126.1" y2="42.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="126.1" y1="42.1" x2="126.1" y2="51.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="126.1" y1="51.1" x2="128.9" y2="59.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="128.9" y1="59.6" x2="134.2" y2="66.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="134.2" y1="66.9" x2="141.4" y2="72.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="141.4" y1="72.2" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="75.0" x2="152.9" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="152.9" y1="75.0" x2="155.7" y2="74.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="155.7" y1="74.9" x2="158.5" y2="74.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="158.5" y1="74.7" x2="161.4" y2="74.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="161.4" y1="74.3" x2="164.2" y2="73.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="164.2" y1="73.8" x2="167.0" y2="73.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="167.0" y1="73.3" x2="169.7" y2="72.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="169.7" y1="72.6" x2="172.5" y2="71.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="172.5" y1="71.8" x2="175.2" y2="70.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="175.2" y1="70.9" x2="177.8" y2="69.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="177.8" y1="69.8" x2="180.5" y2="68.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="180.5" y1="68.7" x2="183.0" y2="67.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="183.0" y1="67.5" x2="185.5" y2="66.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="185.5" y1="66.1" x2="188.0" y2="64.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="188.0" y1="64.7" x2="190.4" y2="63.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="190.4" y1="63.2" x2="192.7" y2="61.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="192.7" y1="61.5" x2="195.0" y2="59.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="195.0" y1="59.8" x2="197.2" y2="58.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="197.2" y1="58.0" x2="199.3" y2="56.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="199.3" y1="56.1" x2="201.4" y2="54.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="201.4" y1="54.1" x2="203.3" y2="52.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="203.3" y1="52.0" x2="205.2" y2="49.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="205.2" y1="49.9" x2="207.0" y2="47.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="207.0" y1="47.6" x2="208.7" y2="45.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="208.7" y1="45.3" x2="210.2" y2="43.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="210.2" y1="43.0" x2="211.7" y2="40.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="211.7" y1="40.5" x2="213.1" y2="38.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="213.1" y1="38.1" x2="214.4" y2="35.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="214.4" y1="35.5" x2="215.6" y2="32.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="215.6" y1="32.9" x2="216.7" y2="30.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="216.7" y1="30.3" x2="217.4" y2="28.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="217.4" y1="28.3" x2="217.7" y2="26.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="217.7" y1="26.2" x2="217.6" y2="24.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="217.6" y1="24.2" x2="217.0" y2="22.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="217.0" y1="22.1" x2="216.0" y2="20.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="216.0" y1="20.3" x2="214.7" y2="18.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="214.7" y1="18.7" x2="213.0" y2="17.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="213.0" y1="17.4" x2="211.1" y2="16.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="211.1" y1="16.5" x2="209.1" y2="16.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="209.1" y1="16.0" x2="207.0" y2="15.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="207.0" y1="15.9" x2="204.9" y2="16.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="204.9" y1="16.3" x2="203.0" y2="17.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="203.0" y1="17.0" x2="201.3" y2="18.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="201.3" y1="18.2" x2="199.8" y2="19.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="199.8" y1="19.7" x2="198.7" y2="21.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="198.7" y1="21.5" x2="198.0" y2="23.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="198.0" y1="23.5" x2="197.7" y2="25.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="197.7" y1="25.5" x2="197.8" y2="27.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="197.8" y1="27.6" x2="198.4" y2="29.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="198.4" y1="29.6" x2="199.4" y2="31.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="199.4" y1="31.5" x2="200.7" y2="33.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="200.7" y1="33.1" x2="202.4" y2="34.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="202.4" y1="34.4" x2="204.3" y2="35.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="204.3" y1="35.3" x2="206.3" y2="35.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="206.3" y1="35.8" x2="208.4" y2="35.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="208.4" y1="35.9" x2="210.5" y2="35.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="210.5" y1="35.5" x2="212.4" y2="34.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="212.4" y1="34.7" x2="214.1" y2="33.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="214.1" y1="33.6" x2="215.6" y2="32.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="215.6" y1="32.1" x2="216.7" y2="30.3"
#     stroke="#663399" stroke-width="2" />
#
# <g transform="rotate(200.0,216.7,30.3) translate(216.7, 30.3)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# In this example, we started with working code and reorganized it with different functions.
# Changes like this, which improve the code without changing its behavior, are called **refactoring**.
#
# If we had planned ahead, we might have written `polyline` first and avoided refactoring, but often you don't know enough at the beginning of a project to design all the functions.
# Once you start coding, you understand the problem better.
# Sometimes refactoring is a sign that you have learned something.

# %% [markdown]
# ## Stack diagram
#
# When we call `circle`, it calls `arc`, which calls `polyline`.
# We can use a stack diagram to show this sequence of function calls and the parameters for each one.

# %%
from diagram import make_binding, make_frame, Frame, Stack

frame1 = make_frame(dict(radius=30), name='circle', loc='left')

frame2 = make_frame(dict(radius=30, angle=360), name='arc', loc='left', dx=1.1)

frame3 = make_frame(dict(n=60, length=3.04, angle=5.8), 
                    name='polyline', loc='left', dx=1.1, offsetx=-0.27)

stack = Stack([frame1, frame2, frame3], dy=-0.4)

# %%
from diagram import diagram, adjust

width, height, x, y = [3.58, 1.31, 0.98, 1.06]
ax = diagram(width, height)
bbox = stack.draw(ax, x, y)
#adjust(x, y, bbox)

# %% [markdown]
# Notice that the value of `angle` in `polyline` is different from the value of `angle` in `arc`.
# Parameters are local, which means you can use the same parameter name in different functions; it's a different variable in each function, and it can refer to a different value.

# %% [markdown]
# ## A development plan
#
# A **development plan** is a process for writing programs.
# The process we used in this chapter is "encapsulation and generalization".
# The steps of this process are:
#
# 1.  Start by writing a small program with no function definitions.
#
# 2.  Once you get the program working, identify a coherent piece of it,
#     encapsulate the piece in a function and give it a name.
#
# 3.  Generalize the function by adding appropriate parameters.
#
# 4.  Repeat Steps 1 to 3 until you have a set of working functions.
#
# 5.  Look for opportunities to improve the program by refactoring. For
#     example, if you have similar code in several places, consider
#     factoring it into an appropriately general function.
#
# This process has some drawbacks -- we will see alternatives later -- but it can be useful if you don't know ahead of time how to divide the program into functions.
# This approach lets you design as you go along.

# %% [markdown]
# The design of a function has two parts:
#
# * The **interface** is how the function is used, including its name, the parameters it takes and what the function is supposed to do.
#
# * The **implementation** is how the function does what it's supposed to do.
#
# For example, here's the first version of `circle` we wrote, which uses `polygon`.

# %%
def circle(radius):
    circumference = 2 * math.pi * radius
    n = 30
    length = circumference / n
    polygon(n, length)

# %% [markdown]
# And here's the refactored version that uses `arc`.

# %%
def circle(radius):
    arc(radius,  360)

# %% [markdown]
# These two functions have the same interface -- they take the same parameters and do the same thing -- but they have different implementations.

# %% [markdown]
# (section_docstring)=
# ## Docstrings
#
# A **docstring** is a string at the beginning of a function that explains the interface ("doc" is short for "documentation").
# Here is an example:

# %%
def polyline(n, length, angle):
    """Draws line segments with the given length and angle between them.
    
    n: integer number of line segments
    length: length of the line segments
    angle: angle between segments (in degrees)
    """    
    for i in range(n):
        forward(length)
        left(angle)

# %% [markdown]
# By convention, docstrings are triple-quoted strings, also known as **multiline strings** because the triple quotes allow the string to span more than one line.
#
# A docstring should:
#
# * Explain concisely what the function does, without getting into the details of how it works,
#
# * Explain what effect each parameter has on the behavior of the function, and
#
# * Indicate what type each parameter should be, if it is not obvious.
#
# Writing this kind of documentation is an important part of interface design.
# A well-designed interface should be simple to explain; if you have a hard time explaining one of your functions, maybe the interface could be improved.

# %% [markdown]
# ## Debugging
#
# An interface is like a contract between a function and a caller. The
# caller agrees to provide certain arguments and the function agrees to
# do certain work.
#
# For example, `polyline` requires three arguments: `n` has to be an integer; `length` should be a positive number; and `angle` has to be a number, which is understood to be in degrees.
#
# These requirements are called **preconditions** because they are supposed to be true before the function starts executing. Conversely, conditions at the end of the function are **postconditions**.
# Postconditions include the intended effect of the function (like drawing line segments) and any side effects (like moving the turtle or making other changes).
#
# Preconditions are the responsibility of the caller. If the caller violates a precondition and the function doesn't work correctly, the bug is in the caller, not the function.
#
# If the preconditions are satisfied and the postconditions are not, the bug is in the function. If your pre- and postconditions are clear, they can help with debugging.

# %% [markdown]
# ## Glossary
#
# **interface design:**
# A process for designing the interface of a function, which includes the parameters it should take.
#
# **canvas:**
# A window used to display graphical elements including lines, circles, rectangles, and other shapes.
#
# **encapsulation:**
#  The process of transforming a sequence of statements into a function definition.
#
# **generalization:**
#  The process of replacing something unnecessarily specific (like a number) with something appropriately general (like a variable or parameter).
#
# **keyword argument:**
# An argument that includes the name of the parameter.
#
# **refactoring:**
#  The process of modifying a working program to improve function interfaces and other qualities of the code.
#
# **development plan:**
# A process for writing programs.
#
# **docstring:**
#  A string that appears at the top of a function definition to document the function's interface.
#
# **multiline string:**
# A string enclosed in triple quotes that can span more than one line of a program.
#
# **precondition:**
#  A requirement that should be satisfied by the caller before a function starts.
#
# **postcondition:**
#  A requirement that should be satisfied by the function before it ends.

# %% [markdown]
# ## Exercises

# %%
# This cell tells Jupyter to provide detailed debugging information
# when a runtime error occurs. Run it before working on the exercises.

# %xmode Verbose
# Out:
# Exception reporting mode: Verbose

# %% [markdown]
# For the exercises below, there are a few more turtle functions you might want to use.
#
# * `penup` lifts the turtle's imaginary pen so it doesn't leave a trail when it moves.
#
# * `pendown` puts the pen back down.
#
# The following function uses `penup` and `pendown` to move the turtle without leaving a trail.

# %%
from jupyturtle import penup, pendown

def jump(length):
    """Move forward length units without leaving a trail.
    
    Postcondition: Leaves the pen down.
    """
    penup()
    forward(length)
    pendown()

# %% [markdown]
# ### Exercise
#
# Write a function called `rectangle` that draws a rectangle with given side lengths.
# For example, here's a rectangle that's `80` units wide and `40` units tall.

# %%
def rectangle(width, length):
    """Draws a rectangle with the given length and width.
    
    width: width of rectangle
    length: length of rectangle
    """ 
    forward(width)
    left(90)
    forward(length)
    left(90)
    forward(width)
    left(90)
    forward(length)
    left(90)

# %% [markdown]
# You can use the following code to test your function.

# %%
make_turtle()
rectangle(80, 40)
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="230.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="230.0" y1="75.0" x2="230.0" y2="35.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="230.0" y1="35.0" x2="150.0" y2="35.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="35.0" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
#
# <g transform="rotate(-90.0,150.0,75.0) translate(150.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# ## Exercise
#
# Write a function called `rhombus` that draws a rhombus with a given side length and a given interior angle. For example, here's a rhombus with side length `50` and an interior angle of `60` degrees.

# %%
def rhombus(side_len, int_ang):
    """Draws a rhombus with the given length and interior angle.
    
    int_ang: smallest interior acute angle
    sid_len: length of side
    """ 
    begin_heading = 90-(int_ang/2)
    left(begin_heading)
    forward(side_len) #1
    left(int_ang)
    forward(side_len) #2
    left(90+(int_ang/2))
    forward(side_len) #3
    left(int_ang)
    forward(side_len) #4
    left(90-(int_ang/2))

# %% [markdown]
# You can use the following code to test your function.

# %%
make_turtle()
right(90)
jump(30)
left(90)
rhombus(50, 60)
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150.0" y1="105.0" x2="175.0" y2="61.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="175.0" y1="61.7" x2="150.0" y2="18.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="18.4" x2="125.0" y2="61.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="125.0" y1="61.7" x2="150.0" y2="105.0"
#     stroke="#663399" stroke-width="2" />
#
# <g transform="rotate(-90.0,150.0,105.0) translate(150.0, 105.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# ### Exercise
#
# Now write a more general function called `parallelogram` that draws a quadrilateral with parallel sides. Then rewrite `rectangle` and `rhombus` to use `parallelogram`.

# %%
def parallelogram(side1,angle,side2):
    """Draws a parallelogram quadrilaterial with given side lengths and angle.
    
    side1: side length 1
    angle: exterior angle between sides
    side2:  side length 2
    """ 
    forward(side1)
    left(angle)
    forward(side2)
    left(180-angle)
    forward(side1)
    left(angle)
    forward(side2)
    left(180-angle)

# %%
make_turtle()
parallelogram(30,50,60)
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="180.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="180.0" y1="75.0" x2="218.6" y2="29.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="218.6" y1="29.0" x2="188.6" y2="29.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="188.6" y1="29.0" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
#
# <g transform="rotate(-90.0,150.0,75.0) translate(150.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %%
def rectangle(side1,side2):
    """ Refactored rectangle to use parallelogram method
    """
    parallelogram(side1,90,side2)

# %%
def rhombus(side_len, int_ang):
    """ Refactored rhombus to use parallelogram method
    """
    parallelogram(side_len,int_ang,side_len)

# %% [markdown]
# You can use the following code to test your functions.

# %%
make_turtle(width=400,delay=0)
jump(-120)

rectangle(80, 40)
jump(100)
rhombus(50, 60)
jump(80)
parallelogram(80, 50, 60)
# Out:
# <svg width="400" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="80.0" y1="75.0" x2="160.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="160.0" y1="75.0" x2="160.0" y2="35.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="160.0" y1="35.0" x2="80.0" y2="35.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="80.0" y1="35.0" x2="80.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="180.0" y1="75.0" x2="230.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="230.0" y1="75.0" x2="255.0" y2="31.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="255.0" y1="31.7" x2="205.0" y2="31.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="205.0" y1="31.7" x2="180.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="260.0" y1="75.0" x2="340.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="340.0" y1="75.0" x2="378.6" y2="29.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="378.6" y1="29.0" x2="298.6" y2="29.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="298.6" y1="29.0" x2="260.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
#
# <g transform="rotate(-90.0,260.0,75.0) translate(260.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# ### Exercise
#
# Write an appropriately general set of functions that can draw shapes like this.
# ![image.png](attachment:9458c79c-653b-4b09-b612-ef9341eaf996.png)
#
# Hint: Write a function called `triangle` that draws one triangular segment, and then a function called `draw_pie` that uses `triangle`.

# %%
def triangle(side_len,top_ang):
    """Draws a triangle with given side length and top angle (smallest acute).
    
    side_len: side length of tallest side of isoceles
    top_ang: interior smallest acute angle
    """ 
    base_ang=(180-top_ang)/2
    base=2*math.sin(top_ang/2*math.pi/180)*side_len
    forward(base)
    left(180-base_ang)
    forward(side_len)
    left(180-top_ang)
    forward(side_len)
    left(180-base_ang)

# %%
make_turtle(delay=0.1)
triangle(80,10)
jump(50)
triangle(80,45)
jump(-100)
triangle(50,60)
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="163.9" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="163.9" y1="75.0" x2="157.0" y2="-4.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="157.0" y1="-4.7" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="200.0" y1="75.0" x2="261.2" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="261.2" y1="75.0" x2="230.6" y2="1.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="230.6" y1="1.1" x2="200.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="100.0" y1="75.0" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="75.0" x2="125.0" y2="31.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="125.0" y1="31.7" x2="100.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
#
# <g transform="rotate(-90.0,100.0,75.0) translate(100.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %%
def draw_pie(num_slices,size):
    """Draws a pie shape with given number of slices and radius of given size.

    num_slices: number of slices of triangle pie for full 360 deg pie
    size: side length of triangle slice = radius of pie
    """ 
    top_angle=360/num_slices
    base=2*math.sin(top_angle/2*math.pi/180)*size
    for i in range(num_slices):
        triangle(size,top_angle)
        jump(base)
        left(top_angle)

# %%
make_turtle(delay=0.2)
draw_pie(5,40)
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="197.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="197.0" y1="75.0" x2="173.5" y2="42.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="173.5" y1="42.6" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="197.0" y1="75.0" x2="211.6" y2="30.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="211.6" y1="30.3" x2="173.5" y2="42.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="173.5" y1="42.6" x2="197.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="211.6" y1="30.3" x2="173.5" y2="2.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="173.5" y1="2.6" x2="173.5" y2="42.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="173.5" y1="42.6" x2="211.6" y2="30.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="173.5" y1="2.6" x2="135.5" y2="30.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="135.5" y1="30.3" x2="173.5" y2="42.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="173.5" y1="42.6" x2="173.5" y2="2.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="135.5" y1="30.3" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="75.0" x2="173.5" y2="42.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="173.5" y1="42.6" x2="135.5" y2="30.3"
#     stroke="#663399" stroke-width="2" />
#
# <g transform="rotate(-90.0,150.0,75.0) translate(150.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# You can use the following code to test your functions.

# %%
make_turtle(delay=0)
jump(-80)

size = 40
draw_pie(5, size)
jump(2*size)
draw_pie(6, size)
jump(2*size)
draw_pie(7, size)
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="70.0" y1="75.0" x2="117.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="117.0" y1="75.0" x2="93.5" y2="42.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="93.5" y1="42.6" x2="70.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="117.0" y1="75.0" x2="131.6" y2="30.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="131.6" y1="30.3" x2="93.5" y2="42.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="93.5" y1="42.6" x2="117.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="131.6" y1="30.3" x2="93.5" y2="2.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="93.5" y1="2.6" x2="93.5" y2="42.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="93.5" y1="42.6" x2="131.6" y2="30.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="93.5" y1="2.6" x2="55.5" y2="30.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="55.5" y1="30.3" x2="93.5" y2="42.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="93.5" y1="42.6" x2="93.5" y2="2.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="55.5" y1="30.3" x2="70.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="70.0" y1="75.0" x2="93.5" y2="42.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="93.5" y1="42.6" x2="55.5" y2="30.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="75.0" x2="190.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="190.0" y1="75.0" x2="170.0" y2="40.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="170.0" y1="40.4" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="190.0" y1="75.0" x2="210.0" y2="40.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="210.0" y1="40.4" x2="170.0" y2="40.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="170.0" y1="40.4" x2="190.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="210.0" y1="40.4" x2="190.0" y2="5.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="190.0" y1="5.7" x2="170.0" y2="40.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="170.0" y1="40.4" x2="210.0" y2="40.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="190.0" y1="5.7" x2="150.0" y2="5.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="5.7" x2="170.0" y2="40.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="170.0" y1="40.4" x2="190.0" y2="5.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="5.7" x2="130.0" y2="40.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="130.0" y1="40.4" x2="170.0" y2="40.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="170.0" y1="40.4" x2="150.0" y2="5.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="130.0" y1="40.4" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="75.0" x2="170.0" y2="40.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="170.0" y1="40.4" x2="130.0" y2="40.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="230.0" y1="75.0" x2="264.7" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="264.7" y1="75.0" x2="247.4" y2="39.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="247.4" y1="39.0" x2="230.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="264.7" y1="75.0" x2="286.4" y2="47.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="286.4" y1="47.9" x2="247.4" y2="39.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="247.4" y1="39.0" x2="264.7" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="286.4" y1="47.9" x2="278.6" y2="14.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="278.6" y1="14.0" x2="247.4" y2="39.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="247.4" y1="39.0" x2="286.4" y2="47.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="278.6" y1="14.0" x2="247.4" y2="-1.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="247.4" y1="-1.0" x2="247.4" y2="39.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="247.4" y1="39.0" x2="278.6" y2="14.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="247.4" y1="-1.0" x2="216.1" y2="14.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="216.1" y1="14.0" x2="247.4" y2="39.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="247.4" y1="39.0" x2="247.4" y2="-1.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="216.1" y1="14.0" x2="208.4" y2="47.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="208.4" y1="47.9" x2="247.4" y2="39.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="247.4" y1="39.0" x2="216.1" y2="14.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="208.4" y1="47.9" x2="230.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="230.0" y1="75.0" x2="247.4" y2="39.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="247.4" y1="39.0" x2="208.4" y2="47.9"
#     stroke="#663399" stroke-width="2" />
#
# <g transform="rotate(270.0,230.0,75.0) translate(230.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# ### Exercise
#
# Write an appropriately general set of functions that can draw flowers like this.
#
# Hint: Use `arc` to write a function called `petal` that draws one flower petal.

# %%
###  The below is before I realized what the flower was - the original image doesnt render here...
make_turtle(delay=0.01,width=300,height=300)
right(90)
jump(50)
left(90)

radius=80
circle(radius)
n=90

# move pie into position
penup()
theta=360/n
base=2*radius*math.sin(theta/2*math.pi/180)
half_base=base/2
shift_up=math.sqrt(radius*radius-half_base*half_base)
arc_length = 2 * math.pi * radius/360
forward(-half_base + 6*arc_length)
left(90)
forward(radius-shift_up)
right(90)
pendown()
draw_pie(n,radius)
#arc(radius=70, angle=70)
# Out:
# <svg width="300" height="300">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150.0" y1="200.0" x2="166.8" y2="200.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="166.8" y1="200.0" x2="183.1" y2="196.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="183.1" y1="196.5" x2="198.5" y2="189.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="198.5" y1="189.7" x2="212.0" y2="179.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="212.0" y1="179.9" x2="223.2" y2="167.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="223.2" y1="167.4" x2="231.6" y2="152.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="231.6" y1="152.9" x2="236.8" y2="137.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="236.8" y1="137.0" x2="238.5" y2="120.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="238.5" y1="120.3" x2="236.8" y2="103.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="236.8" y1="103.6" x2="231.6" y2="87.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="231.6" y1="87.7" x2="223.2" y2="73.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="223.2" y1="73.2" x2="212.0" y2="60.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="212.0" y1="60.7" x2="198.5" y2="50.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="198.5" y1="50.9" x2="183.1" y2="44.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="183.1" y1="44.1" x2="166.8" y2="40.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="166.8" y1="40.6" x2="150.0" y2="40.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="40.6" x2="133.6" y2="44.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="133.6" y1="44.1" x2="118.3" y2="50.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="118.3" y1="50.9" x2="104.7" y2="60.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="104.7" y1="60.7" x2="93.5" y2="73.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="93.5" y1="73.2" x2="85.2" y2="87.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="85.2" y1="87.7" x2="80.0" y2="103.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="80.0" y1="103.6" x2="78.2" y2="120.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="78.2" y1="120.3" x2="80.0" y2="137.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="80.0" y1="137.0" x2="85.2" y2="152.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="85.2" y1="152.9" x2="93.5" y2="167.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="93.5" y1="167.4" x2="104.7" y2="179.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="104.7" y1="179.9" x2="118.3" y2="189.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="118.3" y1="189.7" x2="133.6" y2="196.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="133.6" y1="196.5" x2="150.0" y2="200.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="155.6" y1="200.0" x2="161.2" y2="200.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="161.2" y1="200.0" x2="158.4" y2="120.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="158.4" y1="120.0" x2="155.6" y2="200.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="161.2" y1="200.0" x2="166.7" y2="199.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="166.7" y1="199.6" x2="158.4" y2="120.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="158.4" y1="120.0" x2="161.2" y2="200.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="166.7" y1="199.6" x2="172.3" y2="198.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="172.3" y1="198.8" x2="158.4" y2="120.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="158.4" y1="120.0" x2="166.7" y2="199.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="172.3" y1="198.8" x2="177.7" y2="197.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="177.7" y1="197.6" x2="158.4" y2="120.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="158.4" y1="120.0" x2="172.3" y2="198.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="177.7" y1="197.6" x2="183.1" y2="196.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="183.1" y1="196.1" x2="158.4" y2="120.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="158.4" y1="120.0" x2="177.7" y2="197.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="183.1" y1="196.1" x2="188.3" y2="194.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="188.3" y1="194.2" x2="158.4" y2="120.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="158.4" y1="120.0" x2="183.1" y2="196.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="188.3" y1="194.2" x2="193.4" y2="191.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="193.4" y1="191.9" x2="158.4" y2="120.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="158.4" y1="120.0" x2="188.3" y2="194.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="193.4" y1="191.9" x2="198.4" y2="189.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="198.4" y1="189.3" x2="158.4" y2="120.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="158.4" y1="120.0" x2="193.4" y2="191.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="198.4" y1="189.3" x2="203.1" y2="186.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="203.1" y1="186.3" x2="158.4" y2="120.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="158.4" y1="120.0" x2="198.4" y2="189.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="203.1" y1="186.3" x2="207.6" y2="183.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="207.6" y1="183.0" x2="158.4" y2="120.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="158.4" y1="120.0" x2="203.1" y2="186.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="207.6" y1="183.0" x2="211.9" y2="179.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="211.9" y1="179.5" x2="158.4" y2="120.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="158.4" y1="120.0" x2="207.6" y2="183.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="211.9" y1="179.5" x2="215.9" y2="175.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="215.9" y1="175.6" x2="158.4" y2="120.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="158.4" y1="120.0" x2="211.9" y2="179.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="215.9" y1="175.6" x2="219.7" y2="171.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="219.7" y1="171.4" x2="158.4" y2="120.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="158.4" y1="120.0" x2="215.9" y2="175.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="219.7" y1="171.4" x2="223.1" y2="167.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="223.1" y1="167.0" x2="158.4" y2="120.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="158.4" y1="120.0" x2="219.7" y2="171.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="223.1" y1="167.0" x2="226.2" y2="162.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="226.2" y1="162.4" x2="158.4" y2="120.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="158.4" y1="120.0" x2="223.1" y2="167.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="226.2" y1="162.4" x2="229.0" y2="157.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="229.0" y1="157.6" x2="158.4" y2="120.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="158.4" y1="120.0" x2="226.2" y2="162.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="229.0" y1="157.6" x2="231.5" y2="152.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="231.5" y1="152.5" x2="158.4" y2="120.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="158.4" y1="120.0" x2="229.0" y2="157.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="231.5" y1="152.5" x2="233.6" y2="147.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="233.6" y1="147.4" x2="158.4" y2="120.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="158.4" y1="120.0" x2="231.5" y2="152.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="233.6" y1="147.4" x2="235.3" y2="142.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="235.3" y1="142.1" x2="158.4" y2="120.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="158.4" y1="120.0" x2="233.6" y2="147.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="235.3" y1="142.1" x2="23

# %%
make_turtle(delay=0.1)
right(90)
jump(50)
left(90)
circle(200)
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150.0" y1="125.0" x2="191.9" y2="125.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="191.9" y1="125.0" x2="232.9" y2="116.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="232.9" y1="116.3" x2="271.1" y2="99.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="271.1" y1="99.3" x2="305.0" y2="74.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="305.0" y1="74.6" x2="333.0" y2="43.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="333.0" y1="43.5" x2="354.0" y2="7.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="354.0" y1="7.2" x2="366.9" y2="-32.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="366.9" y1="-32.6" x2="371.3" y2="-74.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="371.3" y1="-74.3" x2="366.9" y2="-115.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="366.9" y1="-115.9" x2="354.0" y2="-155.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="354.0" y1="-155.8" x2="333.0" y2="-192.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="333.0" y1="-192.0" x2="305.0" y2="-223.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="305.0" y1="-223.2" x2="271.1" y2="-247.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="271.1" y1="-247.8" x2="232.9" y2="-264.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="232.9" y1="-264.8" x2="191.9" y2="-273.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="191.9" y1="-273.5" x2="150.0" y2="-273.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="-273.5" x2="109.0" y2="-264.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="109.0" y1="-264.8" x2="70.8" y2="-247.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="70.8" y1="-247.8" x2="36.9" y2="-223.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="36.9" y1="-223.2" x2="8.8" y2="-192.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="8.8" y1="-192.0" x2="-12.1" y2="-155.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="-12.1" y1="-155.8" x2="-25.0" y2="-115.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="-25.0" y1="-115.9" x2="-29.4" y2="-74.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="-29.4" y1="-74.3" x2="-25.0" y2="-32.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="-25.0" y1="-32.6" x2="-12.1" y2="7.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="-12.1" y1="7.2" x2="8.8" y2="43.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="8.8" y1="43.5" x2="36.9" y2="74.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="36.9" y1="74.6" x2="70.8" y2="99.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="70.8" y1="99.3" x2="109.0" y2="116.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="109.0" y1="116.3" x2="150.0" y2="125.0"
#     stroke="#663399" stroke-width="2" />
#
# <g transform="rotate(-90.0,150.0,125.0) translate(150.0, 125.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %%
### PETAL
def petal(radius,angle):
    arc(radius,angle)
    left(180-angle)
    arc(radius,angle)

### FLOWER
def flower(n, radius, angle):
    for i in range(n+1):
        right(angle/2)
        petal(radius,angle)

# %%
make_turtle(delay=0,width=300,height=300)
right(90)
#jump(50)

radius=50
angle=90
n=7

flower(n, radius, angle)
# Out:
# <svg width="300" height="300">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="150" x2="148.1" y2="151.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="148.1" y1="151.9" x2="146.4" y2="153.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="146.4" y1="153.8" x2="144.7" y2="155.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="144.7" y1="155.8" x2="143.2" y2="157.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="143.2" y1="157.9" x2="141.8" y2="160.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="141.8" y1="160.1" x2="140.5" y2="162.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="140.5" y1="162.4" x2="139.3" y2="164.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="139.3" y1="164.7" x2="138.2" y2="167.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="138.2" y1="167.1" x2="137.3" y2="169.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="137.3" y1="169.6" x2="136.5" y2="172.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="136.5" y1="172.1" x2="135.8" y2="174.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="135.8" y1="174.6" x2="135.3" y2="177.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="135.3" y1="177.2" x2="134.8" y2="179.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="134.8" y1="179.7" x2="134.6" y2="182.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="134.6" y1="182.3" x2="134.4" y2="185.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="134.4" y1="185.0" x2="134.4" y2="187.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="134.4" y1="187.6" x2="134.6" y2="190.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="134.6" y1="190.2" x2="134.8" y2="192.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="134.8" y1="192.8" x2="135.3" y2="195.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="135.3" y1="195.4" x2="135.8" y2="197.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="135.8" y1="197.9" x2="136.5" y2="200.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="136.5" y1="200.5" x2="137.3" y2="203.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="137.3" y1="203.0" x2="138.2" y2="205.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="138.2" y1="205.4" x2="139.3" y2="207.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="139.3" y1="207.8" x2="140.5" y2="210.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="140.5" y1="210.1" x2="141.8" y2="212.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="141.8" y1="212.4" x2="143.2" y2="214.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="143.2" y1="214.6" x2="144.7" y2="216.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="144.7" y1="216.7" x2="146.4" y2="218.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="146.4" y1="218.7" x2="148.1" y2="220.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="148.1" y1="220.7" x2="150.0" y2="218.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="218.8" x2="151.8" y2="216.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="151.8" y1="216.9" x2="153.4" y2="214.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="153.4" y1="214.9" x2="154.9" y2="212.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="154.9" y1="212.7" x2="156.4" y2="210.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="156.4" y1="210.5" x2="157.7" y2="208.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="157.7" y1="208.3" x2="158.9" y2="205.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="158.9" y1="205.9" x2="159.9" y2="203.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="159.9" y1="203.6" x2="160.9" y2="201.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="160.9" y1="201.1" x2="161.7" y2="198.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="161.7" y1="198.6" x2="162.4" y2="196.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="162.4" y1="196.1" x2="162.9" y2="193.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="162.9" y1="193.5" x2="163.3" y2="190.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="163.3" y1="190.9" x2="163.6" y2="188.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="163.6" y1="188.3" x2="163.7" y2="185.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="163.7" y1="185.7" x2="163.7" y2="183.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="163.7" y1="183.1" x2="163.6" y2="180.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="163.6" y1="180.5" x2="163.3" y2="177.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="163.3" y1="177.9" x2="162.9" y2="175.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="162.9" y1="175.3" x2="162.4" y2="172.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="162.4" y1="172.7" x2="161.7" y2="170.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="161.7" y1="170.2" x2="160.9" y2="167.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="160.9" y1="167.7" x2="159.9" y2="165.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="159.9" y1="165.3" x2="158.9" y2="162.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="158.9" y1="162.9" x2="157.7" y2="160.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="157.7" y1="160.6" x2="156.4" y2="158.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="156.4" y1="158.3" x2="154.9" y2="156.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="154.9" y1="156.1" x2="153.4" y2="154.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="153.4" y1="154.0" x2="151.8" y2="151.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="151.8" y1="151.9" x2="150.0" y2="150.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="150.0" x2="150.0" y2="147.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="147.4" x2="149.9" y2="144.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="149.9" y1="144.8" x2="149.6" y2="142.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="149.6" y1="142.2" x2="149.2" y2="139.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="149.2" y1="139.6" x2="148.6" y2="137.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="148.6" y1="137.0" x2="148.0" y2="134.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="148.0" y1="134.5" x2="147.1" y2="132.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="147.1" y1="132.0" x2="146.2" y2="129.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="146.2" y1="129.6" x2="145.1" y2="127.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="145.1" y1="127.2" x2="144.0" y2="124.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="144.0" y1="124.8" x2="142.6" y2="122.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="142.6" y1="122.6" x2="141.2" y2="120.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="141.2" y1="120.4" x2="139.7" y2="118.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="139.7" y1="118.2" x2="138.0" y2="116.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="138.0" y1="116.2" x2="136.3" y2="114.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="136.3" y1="114.3" x2="134.4" y2="112.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="134.4" y1="112.4" x2="132.5" y2="110.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="132.5" y1="110.7" x2="130.5" y2="109.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="130.5" y1="109.0" x2="128.3" y2="107.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="128.3" y1="107.5" x2="126.1" y2="106.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="126.1" y1="106.1" x2="123.9" y2="104.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="123.9" y1="104.7" x2="121.5" y2="103.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="121.5" y1="103.6" x2="119.1" y2="102.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="119.1" y1="102.5" x2="116.7" y2="101.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="116.7" y1="101.6" x2="114.2" y2="100.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="114.2" y1="100.7" x2="111.7" y2="100.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="111.7" y1="100.1" x2="109.1" y2="99.5"
#     stroke="#663399" stroke-width="2" />
# <

# %% [markdown]
# You can use the following code to test your functions.
#
# Because the solution draws a lot of small line segments, it tends to slow down as it runs.
# To avoid that, you can add the keyword argument `auto_render=False` to avoid drawing after every step, and then call the `render` function at the end to show the result.
#
# While you are debugging, you might want to remove `auto_render=False`.

# %%
from jupyturtle import render

make_turtle(auto_render=False, width=400,height=300)

jump(-60)
n = 7
radius = 60
angle = 60
flower(n, radius, angle)

jump(120)
n = 9
radius = 40
angle = 85
flower(n, radius, angle)

render()
# Out:
# <svg width="400" height="300">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="140.0" y1="150.0" x2="141.8" y2="151.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="141.8" y1="151.0" x2="143.7" y2="152.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="143.7" y1="152.0" x2="145.5" y2="152.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="145.5" y1="152.9" x2="147.5" y2="153.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="147.5" y1="153.8" x2="149.4" y2="154.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="149.4" y1="154.6" x2="151.4" y2="155.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="151.4" y1="155.3" x2="153.4" y2="155.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="153.4" y1="155.9" x2="155.4" y2="156.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="155.4" y1="156.5" x2="157.4" y2="157.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="157.4" y1="157.0" x2="159.5" y2="157.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="159.5" y1="157.5" x2="161.5" y2="157.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="161.5" y1="157.8" x2="163.6" y2="158.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="163.6" y1="158.1" x2="165.7" y2="158.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="165.7" y1="158.3" x2="167.8" y2="158.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="167.8" y1="158.5" x2="169.9" y2="158.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="169.9" y1="158.6" x2="172.0" y2="158.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="172.0" y1="158.6" x2="174.0" y2="158.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="174.0" y1="158.5" x2="176.1" y2="158.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="176.1" y1="158.3" x2="178.2" y2="158.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="178.2" y1="158.1" x2="180.3" y2="157.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="180.3" y1="157.8" x2="182.4" y2="157.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="182.4" y1="157.5" x2="184.4" y2="157.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="184.4" y1="157.0" x2="186.4" y2="156.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="186.4" y1="156.5" x2="188.4" y2="155.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="188.4" y1="155.9" x2="190.4" y2="155.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="190.4" y1="155.3" x2="192.4" y2="154.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="192.4" y1="154.6" x2="194.3" y2="153.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="194.3" y1="153.8" x2="196.3" y2="152.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="196.3" y1="152.9" x2="198.1" y2="152.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="198.1" y1="152.0" x2="200.0" y2="151.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="200.0" y1="151.0" x2="198.2" y2="150.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="198.2" y1="150.0" x2="196.3" y2="149.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="196.3" y1="149.0" x2="194.4" y2="148.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="194.4" y1="148.1" x2="192.5" y2="147.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="192.5" y1="147.2" x2="190.6" y2="146.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="190.6" y1="146.5" x2="188.6" y2="145.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="188.6" y1="145.7" x2="186.6" y2="145.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="186.6" y1="145.1" x2="184.6" y2="144.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="184.6" y1="144.5" x2="182.6" y2="144.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="182.6" y1="144.0" x2="180.5" y2="143.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="180.5" y1="143.6" x2="178.5" y2="143.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="178.5" y1="143.2" x2="176.4" y2="142.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="176.4" y1="142.9" x2="174.3" y2="142.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="174.3" y1="142.7" x2="172.2" y2="142.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="172.2" y1="142.6" x2="170.1" y2="142.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="170.1" y1="142.5" x2="168.0" y2="142.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="168.0" y1="142.5" x2="165.9" y2="142.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="165.9" y1="142.6" x2="163.9" y2="142.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="163.9" y1="142.7" x2="161.8" y2="142.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="161.8" y1="142.9" x2="159.7" y2="143.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="159.7" y1="143.2" x2="157.6" y2="143.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="157.6" y1="143.6" x2="155.6" y2="144.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="155.6" y1="144.0" x2="153.6" y2="144.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="153.6" y1="144.5" x2="151.5" y2="145.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="151.5" y1="145.1" x2="149.6" y2="145.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="149.6" y1="145.7" x2="147.6" y2="146.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="147.6" y1="146.5" x2="145.6" y2="147.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="145.6" y1="147.2" x2="143.7" y2="148.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="143.7" y1="148.1" x2="141.8" y2="149.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="141.8" y1="149.0" x2="140.0" y2="150.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="140.0" y1="150.0" x2="137.9" y2="150.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="137.9" y1="150.0" x2="135.8" y2="150.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="135.8" y1="150.1" x2="133.7" y2="150.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="133.7" y1="150.2" x2="131.6" y2="150.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="131.6" y1="150.4" x2="129.6" y2="150.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="129.6" y1="150.7" x2="127.5" y2="151.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="127.5" y1="151.1" x2="125.5" y2="151.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="125.5" y1="151.5" x2="123.4" y2="152.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="123.4" y1="152.0" x2="121.4" y2="152.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="121.4" y1="152.6" x2="119.4" y2="153.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="119.4" y1="153.3" x2="117.4" y2="154.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="117.4" y1="154.0" x2="115.5" y2="154.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="115.5" y1="154.8" x2="113.6" y2="155.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="113.6" y1="155.6" x2="111.7" y2="156.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="111.7" y1="156.5" x2="109.9" y2="157.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="109.9" y1="157.5" x2="108.0" y2="158.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="108.0" y1="158.6" x2="106.3" y2="159.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="106.3" y1="159.7" x2="104.5" y2="160.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="104.5" y1="160.8" x2="102.8" y2="162.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="102.8" y1="162.1" x2="101.2" y2="163.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="101.2" y1="163.4" x2="99.6" y2="164.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="99.6" y1="164.7" x2="98.0" y2="166.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="98.0" y1="166.1" x2="96.5" y2="167.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="96.5" y1="167.6" x2="95.1" y2="169.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="95.1" y1="169.1" x2="93.7" y2="170.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="93.7" y1="170.6" x2="92.3" y2="172.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="92.3" y1="172.2" x2="91.0" y2="173.9"
#     stroke="#663399" stroke-width="2" />
# <line x1=

# %% [markdown]
# ### Ask a virtual assistant
#
# There are several modules like `jupyturtle` in Python, and the one we used in this chapter has been customized for this book.
# So if you ask a virtual assistant for help, it won't know which module to use.
# But if you give it a few examples to work with, it can probably figure it out.
# For example, try this prompt and see if it can write a function that draws a spiral:
#
# ```
# The following program uses a turtle graphics module to draw a circle:
#
# from jupyturtle import make_turtle, forward, left
# import math
#
# def polygon(n, length):
#     angle = 360 / n
#     for i in range(n):
#         forward(length)
#         left(angle)
#
# def circle(radius):
#     circumference = 2 * math.pi * radius
#     n = 30
#     length = circumference / n
#     polygon(n, length)
#
# make_turtle(delay=0)
# circle(30)
#
# Write a function that draws a spiral.
# ```

# %% [markdown]
# Keep in mind that the result might use features we have not seen yet, and it might have errors.
# Copy the code from the VA and see if you can get it working.
# If you didn't get what you wanted, try modifying the prompt.

# %%
# from chatGPT:
from jupyturtle import make_turtle, forward, left

def spiral(turn_angle, initial_length, increment, turns):
    length = initial_length
    for i in range(turns):
        forward(length)
        left(turn_angle)
        length += increment
        
make_turtle(delay=0, width=500,height=500)
spiral(turn_angle=30, initial_length=10, increment=1, turns=100)
# Out:
# <svg width="500" height="500">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="250" y1="250" x2="260.0" y2="250.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="260.0" y1="250.0" x2="269.5" y2="244.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="269.5" y1="244.5" x2="275.5" y2="234.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="275.5" y1="234.1" x2="275.5" y2="221.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="275.5" y1="221.1" x2="268.5" y2="209.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="268.5" y1="209.0" x2="255.5" y2="201.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="255.5" y1="201.5" x2="239.5" y2="201.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="239.5" y1="201.5" x2="224.8" y2="210.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="224.8" y1="210.0" x2="215.8" y2="225.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="215.8" y1="225.6" x2="215.8" y2="244.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="215.8" y1="244.6" x2="225.8" y2="261.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="225.8" y1="261.9" x2="244.0" y2="272.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="244.0" y1="272.4" x2="266.0" y2="272.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="266.0" y1="272.4" x2="285.9" y2="260.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="285.9" y1="260.9" x2="297.9" y2="240.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="297.9" y1="240.1" x2="297.9" y2="215.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="297.9" y1="215.1" x2="284.9" y2="192.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="284.9" y1="192.6" x2="261.5" y2="179.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="261.5" y1="179.1" x2="233.5" y2="179.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="233.5" y1="179.1" x2="208.4" y2="193.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="208.4" y1="193.6" x2="193.4" y2="219.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="193.4" y1="219.6" x2="193.4" y2="250.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="193.4" y1="250.6" x2="209.4" y2="278.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="209.4" y1="278.3" x2="238.0" y2="294.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="238.0" y1="294.8" x2="272.0" y2="294.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="272.0" y1="294.8" x2="302.3" y2="277.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="302.3" y1="277.3" x2="320.3" y2="246.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="320.3" y1="246.1" x2="320.3" y2="209.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="320.3" y1="209.1" x2="301.3" y2="176.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="301.3" y1="176.2" x2="267.5" y2="156.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="267.5" y1="156.7" x2="227.5" y2="156.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="227.5" y1="156.7" x2="192.0" y2="177.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="192.0" y1="177.2" x2="171.0" y2="213.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="171.0" y1="213.6" x2="171.0" y2="256.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="171.0" y1="256.6" x2="193.0" y2="294.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="193.0" y1="294.7" x2="232.0" y2="317.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="232.0" y1="317.2" x2="278.0" y2="317.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="278.0" y1="317.2" x2="318.7" y2="293.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="318.7" y1="293.7" x2="342.7" y2="252.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="342.7" y1="252.1" x2="342.7" y2="203.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="342.7" y1="203.1" x2="317.7" y2="159.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="317.7" y1="159.8" x2="273.5" y2="134.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="273.5" y1="134.3" x2="221.5" y2="134.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="221.5" y1="134.3" x2="175.6" y2="160.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="175.6" y1="160.8" x2="148.6" y2="207.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="148.6" y1="207.6" x2="148.6" y2="262.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="148.6" y1="262.6" x2="176.6" y2="311.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="176.6" y1="311.1" x2="226.0" y2="339.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="226.0" y1="339.6" x2="284.0" y2="339.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="284.0" y1="339.6" x2="335.1" y2="310.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="335.1" y1="310.1" x2="365.1" y2="258.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="365.1" y1="258.1" x2="365.1" y2="197.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="365.1" y1="197.1" x2="334.1" y2="143.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="334.1" y1="143.4" x2="279.5" y2="111.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="279.5" y1="111.9" x2="215.5" y2="111.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="215.5" y1="111.9" x2="159.2" y2="144.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="159.2" y1="144.4" x2="126.2" y2="201.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="126.2" y1="201.6" x2="126.2" y2="268.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="126.2" y1="268.6" x2="160.2" y2="327.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="160.2" y1="327.5" x2="220.0" y2="362.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="220.0" y1="362.0" x2="290.0" y2="362.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="290.0" y1="362.0" x2="351.5" y2="326.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="351.5" y1="326.5" x2="387.5" y2="264.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="387.5" y1="264.1" x2="387.5" y2="191.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="387.5" y1="191.1" x2="350.5" y2="127.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="350.5" y1="127.0" x2="285.5" y2="89.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="285.5" y1="89.5" x2="209.5" y2="89.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="209.5" y1="89.5" x2="142.9" y2="128.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="142.9" y1="128.0" x2="103.9" y2="195.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="103.9" y1="195.6" x2="103.9" y2="274.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="103.9" y1="274.6" x2="143.9" y2="343.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="143.9" y1="343.9" x2="214.0" y2="384.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="214.0" y1="384.4" x2="296.0" y2="384.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="296.0" y1="384.4" x2="367.9" y2="342.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="367.9" y1="342.9" x2="409.9" y2="270.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="409.9" y1="270.1" x2="409.9" y2="185.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="409.9" y1="185.1" x2="366.9" y2="110.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="366.9" y1="110.6" x2="291.5" y2="67.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="291.5" y1="67.1" x2="203.5" y2="67.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="203.5" y1="67.1" x2="126.5" y2="111.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="126.5" y1="111.6" x2="81.5" y2="189.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="81.5" y1="189.6" x2="81.5" y2="280.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="81.5" y1="280.6" x2="127.5" y2="360.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="127.5" y1="360.2" x2="208.0" y2="406.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="208.0" y1="406.7" x2="302.0" y2="406.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="302.0" y1="406.7" x2="384.3" y2="359.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="384.3" y1="359.2" x2="432.3" y2="276.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="43
